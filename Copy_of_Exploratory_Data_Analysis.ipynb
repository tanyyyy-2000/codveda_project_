# %%
#Description: Performed an exploratory Analysis on a given Dataset to identify patterns , Trends and summary statistics
#Tools used : Python,Pandas, matplotlib,seaborn
# !pip install Pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/3) Sentiment dataset.csv')
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
#Calculating Summary Statistics (mean,median,mode, Standard Deviation)

# %%
dataset.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
#performing summary statistics for a single column for instance

# %%
dataset['Retweets'].mean()
# Out:
# np.float64(21.508196721311474)

# %%
dataset['Retweets'].median()
# Out:
# 22.0

# %%
dataset['Retweets'].mode()
# Out:
# 0    22.0
# Name: Retweets, dtype: float64

# %%
dataset['Retweets'].min()
# Out:
# 5.0

# %%
dataset['Retweets'].max()
# Out:
# 40.0

# %%
dataset['Retweets'].std()
# Out:
# 7.061286414470437

# %%
dataset['Retweets'].var()
# Out:
# 49.861765827184755

# %%
dataset['Retweets'].quantile()
# Out:
# np.float64(22.0)

# %%
dataset['Retweets'].sum()
# Out:
# np.float64(15744.0)

# %%
dataset['Likes'].sum()
# Out:
# np.float64(31404.0)

# %%
#Visualize Data Distributions using Histogram , boxplots and scatter plots
plt.boxplot(dataset['Retweets'])
plt.show()

# %%
plt.hist(dataset['Retweets'])
plt.show()

# %%
plt.boxplot(dataset['Likes'])
plt.show()

# %%
plt.hist(dataset['Likes'])
plt.show()

# %%
dataset['Retweets'].quantile(0.4)
# Out:
# np.float64(20.0)

# %%
dataset['Retweets'].cumsum().head()
# Out:
# 0    15.0
# 1    20.0
# 2    40.0
# 3    48.0
# 4    60.0
# Name: Retweets, dtype: float64

# %%
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
#finding correlations between numerical features

# %%
corr_matrix = dataset.select_dtypes(include='number').corr()
corr_matrix
# Out:
#               Unnamed: 0.1  Unnamed: 0  Retweets     Likes      Year  \
# Unnamed: 0.1      1.000000    0.999995  0.388637  0.376208  0.101578
# Unnamed: 0        0.999995    1.000000  0.388884  0.376472  0.100749
# Retweets          0.388637    0.388884  1.000000  0.998482 -0.039982
# Likes             0.376208    0.376472  0.998482  1.000000 -0.043415
# Year              0.101578    0.100749 -0.039982 -0.043415  1.000000
# Month             0.443013    0.443523  0.073265  0.066643 -0.314845
# Day              -0.080101   -0.080480  0.009213  0.011489  0.021973
# Hour              0.322371    0.322163  0.196955  0.195331 -0.087470
#
#                  Month       Day      Hour
# Unnamed: 0.1  0.443013 -0.080101  0.322371
# Unnamed: 0    0.443523 -0.080480  0.322163
# Retweets      0.073265  0.009213  0.196955
# Likes         0.066643  0.011489  0.195331
# Year         -0.314845  0.021973 -0.087470
# Month         1.000000 -0.135873  0.137835
# ...

# %%
corr_matrix["Retweets"]
# Out:
# Unnamed: 0.1    0.388637
# Unnamed: 0      0.388884
# Retweets        1.000000
# Likes           0.998482
# Year           -0.039982
# Month           0.073265
# Day             0.009213
# Hour            0.196955
# Name: Retweets, dtype: float64

# %%
corr_matrix["Likes"]
# Out:
# Unnamed: 0.1    0.376208
# Unnamed: 0      0.376472
# Retweets        0.998482
# Likes           1.000000
# Year           -0.043415
# Month           0.066643
# Day             0.011489
# Hour            0.195331
# Name: Likes, dtype: float64

# %%
corr_matrix["Hour"]
# Out:
# Unnamed: 0.1    0.322371
# Unnamed: 0      0.322163
# Retweets        0.196955
# Likes           0.195331
# Year           -0.087470
# Month           0.137835
# Day             0.044072
# Hour            1.000000
# Name: Hour, dtype: float64

# %%
corr_matrix["Day"]
# Out:
# Unnamed: 0.1   -0.080101
# Unnamed: 0     -0.080480
# Retweets        0.009213
# Likes           0.011489
# Year            0.021973
# Month          -0.135873
# Day             1.000000
# Hour            0.044072
# Name: Day, dtype: float64
